# %% [markdown]
# ### Preprocess CSV files
# - 기존 CSV 파일 내 빈칸 채워넣기
# - 식품 카테고리 확정

# %%
import pandas as pd

# %% [markdown]
# 1. (1) Food Data -> processed_food
# - `제조국가` : "대한민국"으로 입력
# - `유통바코드` : 전체 임의의 숫자로 입력
# - `식품대분류` 및 `식품상세분류` : 식품 카테고리 추출

# %%
food_data = pd.read_csv('original/processed_food.csv', header=1, low_memory=False)
food_data.head()
# Out:
#    id       food_code    food_name country_origin manufacturer category_main  \
# 0   1  P000001-ZZ-AVG       구운 인절미           대한민국     해태가루비(주)            과자
# 1   2  P000003-ZZ-AVG    코펜라스 버터쿠키            NaN        매크로통상            과자
# 2   3  P000004-ZZ-AVG  로아커 웨하스 바닐라            NaN         ㈜델리팜            과자
# 3   4  P000005-ZZ-AVG        맛미 강정            NaN         왕궁병과            과자
# 4   5  P000006-ZZ-AVG        찹쌀 약과            NaN         성진식품            과자
#
#   category_sub  food_image  allergy_info  storage_info  barcode_no
# 0         스낵과자         NaN           NaN           NaN         NaN
# 1           쿠키         NaN           NaN           NaN         NaN
# 2          웨이퍼         NaN           NaN           NaN         NaN
# 3          한과류         NaN           NaN           NaN         NaN
# 4          한과류         NaN           NaN           NaN         NaN

# %%
id_col = list(range(1, len(food_data)+1))
food_data['id'] = pd.DataFrame({'id' : id_col})

# %%
# is_blank = (processed_food['country_origin'] == '')
# processed_food.loc[is_blank, 'country_origin'] = '대한민국

food_data['country_origin'] = food_data['country_origin'].replace(to_replace=[None], value='대한민국')
food_data.head()
# Out:
#    id       food_code    food_name country_origin manufacturer category_main  \
# 0   1  P000001-ZZ-AVG       구운 인절미           대한민국     해태가루비(주)            과자
# 1   2  P000003-ZZ-AVG    코펜라스 버터쿠키           대한민국        매크로통상            과자
# 2   3  P000004-ZZ-AVG  로아커 웨하스 바닐라           대한민국         ㈜델리팜            과자
# 3   4  P000005-ZZ-AVG        맛미 강정           대한민국         왕궁병과            과자
# 4   5  P000006-ZZ-AVG        찹쌀 약과           대한민국         성진식품            과자
#
#   category_sub  food_image  allergy_info  storage_info  barcode_no
# 0         스낵과자         NaN           NaN           NaN         NaN
# 1           쿠키         NaN           NaN           NaN         NaN
# 2          웨이퍼         NaN           NaN           NaN         NaN
# 3          한과류         NaN           NaN           NaN         NaN
# 4          한과류         NaN           NaN           NaN         NaN

# %%
import random

random.shuffle(id_col)
barcode_col = [i+8809647000000 for i in id_col]
food_data['barcode_no'] = pd.DataFrame({'barcode_no' : barcode_col})

food_data.head()
# Out:
#    id       food_code    food_name country_origin manufacturer category_main  \
# 0   1  P000001-ZZ-AVG       구운 인절미           대한민국     해태가루비(주)            과자
# 1   2  P000003-ZZ-AVG    코펜라스 버터쿠키           대한민국        매크로통상            과자
# 2   3  P000004-ZZ-AVG  로아커 웨하스 바닐라           대한민국         ㈜델리팜            과자
# 3   4  P000005-ZZ-AVG        맛미 강정           대한민국         왕궁병과            과자
# 4   5  P000006-ZZ-AVG        찹쌀 약과           대한민국         성진식품            과자
#
#   category_sub  food_image  allergy_info  storage_info     barcode_no
# 0         스낵과자         NaN           NaN           NaN  8809647034523
# 1           쿠키         NaN           NaN           NaN  8809647060429
# 2          웨이퍼         NaN           NaN           NaN  8809647032596
# 3          한과류         NaN           NaN           NaN  8809647043033
# 4          한과류         NaN           NaN           NaN  8809647016985

# %%
processed_category_main = food_data['category_main'].to_list()
processed_category_sub = food_data['category_sub'].to_list()

processed_category_all = list(zip(processed_category_main, processed_category_sub))
print(processed_category_all[:10])
# Out:
# [('과자', '스낵과자'), ('과자', '쿠키'), ('과자', '웨이퍼'), ('과자', '한과류'), ('과자', '한과류'), ('과자', '쿠키'), ('과자', '웨이퍼'), ('과자', '스낵과자'), ('과자', '한과류'), ('과자', '스낵과자')]

# %%
food_data.to_csv('new/processed_food.csv', index=False)

# %% [markdown]
# 1. (2) Food Data -> fresh_food
# - `제조국가` : "대한민국"으로 입력
# - `채취시기` : 빈칸인 경우에 한해서만 "평균"으로 입력
# - `식품대분류` 및 `식품상세분류` : 식품 카테고리 추출

# %%
food_data = pd.read_csv('original/fresh_food.csv', header=1)
food_data.head()
# Out:
#    id       food_code            food_name country_origin manufacturer  \
# 0   1  R000001-ZZ-AVG      귀리, 겉귀리, 도정, 생것           대한민국       전국(대표)
# 1   2  R000002-ZZ-AVG      귀리, 쌀귀리, 도정, 생것            NaN       전국(대표)
# 2   3  R000003-ZZ-AVG  귀리, 쌀귀리, 대양, 도정, 생것            NaN       전국(대표)
# 3   4  R000004-ZZ-AVG  귀리, 쌀귀리, 조양, 도정, 생것            NaN       전국(대표)
# 4   5  R000005-ZZ-AVG       귀리, 쌀귀리, 도정, 밥            NaN       전국(대표)
#
#   category_main category_sub  food_image  allergy_info  storage_info  \
# 0          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 1          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 2          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 3          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 4          농축산물    곡류 및 그 제품         NaN           NaN           NaN
#
#   harvest_time
# 0           평균
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
id_col = list(range(1, len(food_data)+1))
food_data['id'] = pd.DataFrame({'id' : id_col})

# %%
food_data['country_origin'] = food_data['country_origin'].replace(to_replace=[None], value='대한민국')
food_data['harvest_time'] = food_data['harvest_time'].replace(to_replace=[None], value='평균')
food_data.head()
# Out:
#    id       food_code            food_name country_origin manufacturer  \
# 0   1  R000001-ZZ-AVG      귀리, 겉귀리, 도정, 생것           대한민국       전국(대표)
# 1   2  R000002-ZZ-AVG      귀리, 쌀귀리, 도정, 생것           대한민국       전국(대표)
# 2   3  R000003-ZZ-AVG  귀리, 쌀귀리, 대양, 도정, 생것           대한민국       전국(대표)
# 3   4  R000004-ZZ-AVG  귀리, 쌀귀리, 조양, 도정, 생것           대한민국       전국(대표)
# 4   5  R000005-ZZ-AVG       귀리, 쌀귀리, 도정, 밥           대한민국       전국(대표)
#
#   category_main category_sub  food_image  allergy_info  storage_info  \
# 0          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 1          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 2          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 3          농축산물    곡류 및 그 제품         NaN           NaN           NaN
# 4          농축산물    곡류 및 그 제품         NaN           NaN           NaN
#
#   harvest_time
# 0           평균
# 1           평균
# 2           평균
# 3           평균
# 4           평균

# %%
fresh_category_main = food_data['category_main'].to_list()
fresh_category_sub = food_data['category_sub'].to_list()

fresh_category_all = list(zip(fresh_category_main, fresh_category_sub))
print(fresh_category_all[:10])
# Out:
# [('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품'), ('농축산물', '곡류 및 그 제품')]

# %%
food_data.to_csv('new/fresh_food.csv', index=False)
